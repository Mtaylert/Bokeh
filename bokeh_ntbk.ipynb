# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, CategoricalColorMapper
import numpy as np

color_list = ['firebrick','wheat','blue','darkcyan','aqua','magenta']

size_list = [4,6,8,12,18,24]
alpha_list = [1,1,0.8,0.6,0.4,0.2]

p = figure(plot_width=300, plot_height=300)
p.circle(x=[1,2,3,4,5,6], y=[2,-1,8,5,3,4],
        size=size_list, alpha=alpha_list, color=color_list)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a91f9b8d-8804-4bfa-899b-d515adb8941d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b05c716f-cf9f-4cfe-8bcb-66991b4556a6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
p = figure(plot_width=300, plot_height=300)
p.line(x=[1,2,3,4,5,6], y=[2,-1,8,5,3,4])
p.line(x=[1,2,3,4,5,6], y=[-2,-1,5,5,3,1], color='red')

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1de1a277-7d0b-4b7a-808e-b7a8f0d2e1b3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ef45cc40-9bf6-4cf2-95de-f920345e24b1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
#patches

class plotting_the_stuff:
    def __init__(self):
        self.plot_size = figure(plot_width=300, plot_height=300)
    def plot_params(self):
        self.plot_size.patch(x=[1,2,3,4,5,6],y=[2,-1,8,5,3,4], alpha=0.5)
        self.plot_size.patch(x=[1,2,3,4,5,6], y=[1,1,1,1,4,6], alpha=0.5, color='red')
        
    def run_program(self):
        self.plot_params()
        output_notebook()
        show(self.plot_size)
        
        
plotting = plotting_the_stuff()
plotting.run_program()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dfd75c09-2684-49f1-92e4-730bd0c31274">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="27946fa4-f464-4d19-95dc-488042d76da2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
import numpy as np
p = figure(plot_width=300, plot_height=300)

x = np.linspace(0,10,101)
y = np.exp(x)

p.circle(x,y)
output_notebook()
show(p)
print(type(x))
print(type(y))
#esc + d two times deletes blank python notebook lines
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="37f6ce54-0e36-42a6-9b65-660d464e50c8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3987f0d1-d54a-4530-aa38-73a7aa925c89"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
import pandas as pd
demo = pd.read_excel('demograph.xlsx')

y = demo['p_asian']
x = demo['UPT']
y2 = demo['p_aa']
y3 = demo['p_hispanic']

p = figure(plot_width=500, plot_height=300,
          x_axis_label='UPT',
          y_axis_label='% population')
p.circle(x,y,color='red')
p.circle(x,y2)
p.circle(x,y3,color='green')
output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c9c9f225-3d61-4e6a-88a4-f605648000de">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="379ae18f-db24-4a33-9cc8-ef8c70b559f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
import pandas as pd
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, CategoricalColorMapper

demo = pd.read_excel('demograph.xlsx')

p_basic = figure(plot_width=500, plot_height=300,
          x_axis_label='UPT',
          y_axis_label='% population')


color_mapper = CategoricalColorMapper(factors=['second city', 'urban', 'suburban','town'],
                                     palette=['red','blue','green','magenta'])

p_basic.circle(demo['UPT'],
              demo['Urbanicity'],
              color={'field':'Urbanicity','transform':color_mapper},
              legend='OK')

output_notebook()
show(p_basic)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16c2cf0c-c119-4273-9048-64038f0881b8">Loading BokehJS ...</span>
#     </div>
# E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Urbanicity [renderer: GlyphRenderer(id='710a1049-be9e-4344-9c36-cf4d78ebbfd7', ...)]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="be888668-c63d-44b7-a603-2b8978012ecd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
# ...
